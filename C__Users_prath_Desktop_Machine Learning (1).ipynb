# %% [markdown]
# # Importing the Libraies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the data

# %%
header = ["variance", "skew", "curtsies", "entropy", "classes"]
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"
df = pd.read_csv(url, names=header)

# %%
df.head()
# Out:
#    variance    skew  curtsies  entropy  classes
# 0   3.62160  8.6661   -2.8073 -0.44699        0
# 1   4.54590  8.1674   -2.4586 -1.46210        0
# 2   3.86600 -2.6383    1.9242  0.10645        0
# 3   3.45660  9.5228   -4.0112 -3.59440        0
# 4   0.32924 -4.4552    4.5718 -0.98880        0

# %% [markdown]
# # Performing descriptive analysis and determining if the data contain null values.

# %% [markdown]
# # Is null() command is used to check if the give data has any NULL values, If will return if the given data any null values or else it will return false.

# %%
df.isnull()
# Out:
#       variance   skew  curtsies  entropy  classes
# 0        False  False     False    False    False
# 1        False  False     False    False    False
# 2        False  False     False    False    False
# 3        False  False     False    False    False
# 4        False  False     False    False    False
# ...        ...    ...       ...      ...      ...
# 1367     False  False     False    False    False
# 1368     False  False     False    False    False
# 1369     False  False     False    False    False
# 1370     False  False     False    False    False
# 1371     False  False     False    False    False
#
# [1372 rows x 5 columns]

# %% [markdown]
# # isnull.sum() will give the column-wise sum of missing values

# %%
df.isnull().sum()
# Out:
# variance    0
# skew        0
# curtsies    0
# entropy     0
# classes     0
# dtype: int64

# %% [markdown]
# # Visualization of data using seaborn library(sns) pairplot method

# %%
g = sns.pairplot(df, hue='classes', markers='+')
plt.show()

# %%
df.hist(edgecolor = 'white', figsize = (20,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019090903970>,
# ...
#       dtype=object)

# %% [markdown]
# # Preparing the train set and the test set with 40% as test size and randon_state=1 to see constant output,and Y axis as classes.

# %%
X = df.drop(['classes'], axis=1)
y = df['classes']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40, random_state=1)

# %% [markdown]
# #  Getting the prediction value, Calculating the accuracy of the model

# %%
y_pred = ppn.predict(X_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9817850637522769

# %%
y_test
# Out:
# 126     0
# 7       0
# 1082    1
# 188     0
# 719     0
#        ..
# 1150    1
# 876     1
# 642     0
# 348     0
# 297     0
# Name: classes, Length: 549, dtype: int64

# %% [markdown]
# # Train the model with a subset of the features and compare the accuracy with last step
#  dropping the varience from X and keeping Y as classes.

# %%
X = df.drop(['classes','variance'], axis=1)
y = df['classes']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40, random_state=1)

# %%
y_pred = ppn.predict(X_test)

# %%
y_test
# Out:
# 126     0
# 7       0
# 1082    1
# 188     0
# 719     0
#        ..
# 1150    1
# 876     1
# 642     0
# 348     0
# 297     0
# Name: classes, Length: 549, dtype: int64

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7905282331511839

# %%
X = df.drop(['classes','variance' , 'skew'], axis=1)
y = df['classes']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40, random_state=1)

# %%
y_pred = ppn.predict(X_test)

# %%
y_test
# Out:
# 126     0
# 7       0
# 1082    1
# 188     0
# 719     0
#        ..
# 1150    1
# 876     1
# 642     0
# 348     0
# 297     0
# Name: classes, Length: 549, dtype: int64

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.4426229508196721

# %%
X = df.drop(['classes','variance' , 'skew', 'curtsies'], axis=1)
y = df['classes']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40, random_state=1)

# %%
y_pred = ppn.predict(X_test)

# %%
y_test
# Out:
# 126     0
# 7       0
# 1082    1
# 188     0
# 719     0
#        ..
# 1150    1
# 876     1
# 642     0
# 348     0
# 297     0
# Name: classes, Length: 549, dtype: int64

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.5409836065573771
